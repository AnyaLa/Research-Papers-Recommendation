# %%
import pandas as pd
import networkx as nx
import numpy as np

from sklearn.linear_model import LogisticRegression

# %%
from tqdm import tqdm

# %%
import random

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %%
def class_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
                     
    y_pred_train = model.predict_proba(X_train)
    y_pred_test = model.predict_proba(X_test)
    
    precision_train = precision_score(y_train, y_pred_train)
    precision_test = precision_score(y_test, y_pred_test)
    accuracy_train = accuracy_score(y_train, y_pred_train)
    accuracy_test = accuracy_score(y_test, y_pred_test)
    f1_macro_train = f1_score(y_train, y_pred_train, average='macro')
    f1_macro_test = f1_score(y_test, y_pred_test, average='macro')
    f1_micro_train = f1_score(y_train, y_pred_train, average='micro')
    f1_micro_test = f1_score(y_test, y_pred_test, average='micro')
    logloss_train = log_loss(y_train, y_pred_train)
    logloss_test = log_loss(y_test, y_pred_test)
    roc_auc_train = roc_auc_score(y_train, y_pred_train)
    roc_auc_test = roc_auc_score(y_test, y_pred_test)

    return model, y_pred_train, y_pred_test, \
        precision_train, precision_test, accuracy_train, accuracy_test, \
        f1_macro_train, f1_macro_test, f1_micro_train, f1_micro_test, \
        roc_auc_train, roc_auc_test, logloss_train, logloss_test

# %%
# LogReg
model = LogisticRegression()

# %%
aan_links = pd.read_csv('links_with_abstract.csv')

# %%
aan_links.head()
# Out:
#      citing     cited
# 0  C08-3004  A00-1002
# 1  D09-1141  A00-1002
# 2  D12-1027  A00-1002
# 3  E06-1047  A00-1002
# 4  H05-1110  A00-1002

# %%
aan_links.shape
# Out:
# (75009, 2)

# %%
aan_meta = pd.read_csv('metadata_with_abstract.csv')

# %%
aan_meta.head()
# Out:
#          id                                    author  \
# 0  E03-1062                               Piwek, Paul
# 1  E06-1001                          McConville, Mark
# 2  E06-1002  Bunescu, Razvan C.; Pa&scedil;ca, Marius
# 3  E06-1003          Tanev, Hristo; Magnini, Bernardo
# 4  E06-1004      Udupa, Raghavendra; Maji, Hemanta K.
#
#                                                title venue  year
# 0  A Flexible Pragmatics-Driven Language Generato...  EACL  2003
# 1                    Inheritance And The CCG Lexicon  EACL  2006
# 2  Using Encyclopedic Knowledge For Named Entity ...  EACL  2006
# 3  Weakly Supervised Approaches For Ontology Popu...  EACL  2006
# 4  Computational Complexity Of Statistical Machin...  EACL  2006

# %%
years = aan_meta[['id','year']]

# %%
years.columns = ['citing', 'year_citing']

# %%
aan_links = aan_links.merge(years, how = 'left', on = 'citing')

# %%
aan_links[aan_links.year_citing > 0].shape
# Out:
# (75009, 3)

# %%
aan_links.groupby('year_citing').size()
# Out:
# year_citing
# 1982        2
# 1983        1
# 1984        2
# 1986        5
# 1987       11
# 1988       33
# 1989       18
# 1990       55
# 1991       33
# 1992       49
# 1993       31
# 1994       76
# 1995       73
# 1996      133
# 1997      163
# 1998      167
# 1999      137
# 2000      305
# 2001      290
# 2002      569
# 2003      856
# 2004     1849
# 2005     1983
# 2006     3721
# 2007     3922
# 2008     4505
# 2009     5746
# 2010     9371
# 2011     7454
# 2012     8929
# 2013    12915
# 2014    11580
# 2015       22
# 2016        3
# dtype: int64

# %%
G = nx.DiGraph()

for i in tqdm(aan_links.index):
    G.add_edge(aan_links.iloc[i]['citing'], aan_links.iloc[i]['cited'])
# Out:
# 100%|██████████████████████████████████| 75009/75009 [00:41<00:00, 1793.08it/s]

# %%
print(nx.info(G))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 13757
# Number of edges: 75009
# Average in degree:   5.4524
# Average out degree:   5.4524

# %%
nodes = list(G.nodes())

# %%
len(nodes)
# Out:
# 13757

# %%
G_train = nx.DiGraph()

for i in tqdm(aan_links[aan_links['year_citing'] < 2013].index):
    G_train.add_edge(aan_links.iloc[i]['citing'], aan_links.iloc[i]['cited'])
# Out:
# 100%|███████████████████████████████████| 50489/50489 [00:53<00:00, 952.05it/s]

# %%
nodes_train = list(G_train.nodes())

# %%
len(nodes_train)
# Out:
# 10588

# %%
cites = pd.DataFrame({'cites_count': aan_links.groupby('citing').size()}).reset_index()

# %%
cites = cites.merge(years, how='left', on='citing')

# %%
cites[cites.year_citing > 2012]
# Out:
#          citing  cites_count  year_citing
# 793    C14-1002           14         2014
# 794    C14-1003           12         2014
# 795    C14-1004            5         2014
# 796    C14-1005           12         2014
# 797    C14-1006            6         2014
# 798    C14-1008           10         2014
# 799    C14-1009           18         2014
# 800    C14-1010            7         2014
# 801    C14-1011            3         2014
# 802    C14-1012            4         2014
# 803    C14-1013            1         2014
# 804    C14-1014            2         2014
# 805    C14-1015            5         2014
# 806    C14-1016            6         2014
# 807    C14-1017            1         2014
# 808    C14-1018           18         2014
# 809    C14-1019            4         2014
# 810    C14-1020            7         2014
# 811    C14-1021            3         2014
# 812    C14-1022            6         2014
# 813    C14-1023            2         2014
# 814    C14-1025           10         2014
# 815    C14-1026           20         2014
# 816    C14-1027           18         2014
# 817    C14-1028            6         2014
# 818    C14-1029            4         2014
# 819    C14-1030            4         2014
# 820    C14-1031            5         2014
# 821    C14-1032            1         2014
# 822    C14-1033            7         2014
# ...         ...          ...          ...
# 12191  W14-5806            1         2014
# 12192  W14-5808            5         2014
# 12193  W14-5809            3         2014
# 12194  W14-5814            2         2014
# 12195  W14-5815            1         2014
# 12196  W14-5818            4         2014
# 12197  W14-5819            3         2014
# 12198  W14-5902            4         2014
# 12199  W14-5903            5         2014
# 12200  W14-5905            4         2014
# 12201  W14-5906            3         2014
# 12202  W14-5907            1         2014
# 12203  W14-6003            6         2014
# 12204  W14-6004            4         2014
# 12205  W14-6005            3         2014
# 12206  W14-6006            1         2014
# 12207  W14-6101           14         2014
# 12208  W14-6102            8         2014
# 12209  W14-6103            3         2014
# 12210  W14-6104            9         2014
# 12211  W14-6105           10         2014
# 12212  W14-6106            3         2014
# 12213  W14-6107            4         2014
# 12214  W14-6108            6         2014
# 12215  W14-6109            5         2014
# 12216  W14-6202            2         2014
# 12217  W14-6203            8         2014
# 12218  W14-6204            1         2014
# 12219  W14-6205            3         2014
# 12220  W14-6206            2         2014
#
# [3043 rows x 3 columns]

# %%
aan_links
# Out:
#          citing     cited  year_citing
# 0      C08-3004  A00-1002         2008
# 1      D09-1141  A00-1002         2009
# 2      D12-1027  A00-1002         2012
# 3      E06-1047  A00-1002         2006
# 74996     4.0
# 74997    13.0
# 74998    10.0
# 74999     1.0
# 75000    20.0
# 75001     1.0
# 75002     7.0
# 75003     8.0
# 75004    14.0
# 75005     7.0
# 75006     1.0
# 75007     5.0
# 75008     3.0
# Name: cited, Length: 75009, dtype: float64

# %%
# df['Rank'] = df.groupby(by=['C1'])['C2'].transform(lambda x: x.rank())
aan_links['cite_rank'] = aan_links.groupby('citing')['cited'].transform(lambda x: x.rank())

# %%
years.columns = ['cited', 'year_cited']

# %%
aan_links = aan_links.merge(years, how='left', on = 'cited')

# %%
aan_links.sort_values(by = ['year_citing','citing'])
# Out:
#          citing     cited  year_citing  cite_rank  year_cited
# 18505  P82-1015  J79-1061         1982        1.0        1979
# 52144  P82-1015  P82-1015         1982        2.0        1982
# 52139  A83-1015  P82-1015         1983        1.0        1982
# 585    P84-1023  A83-1007         1984        1.0        1983
# 52146  P84-1065  P83-1012         1984        1.0        1983
# 4904   C86-1041  C86-1019         1986        1.0        1986
# 52138  C86-1138  P81-1032         1986        1.0        1981
# 52188  C86-1139  P85-1019         1986        1.0        1985
# 52156  C86-1147  P85-1004         1986        1.0        1985
# 52192  H86-1007  P86-1036         1986        1.0        1986
# 52190  P87-1005  P86-1005         1987        1.0        1986
# 52193  P87-1005  P86-1036         1987        2.0        1986
# 4926   P87-1014  C86-1137         1987        1.0        1986
# 52147  P87-1014  P84-1065         1987        2.0        1984
# 4914   P87-1018  C86-1045         1987        1.0        1986
# 4933   P87-1018  C86-1147         1987        2.0        1986
# 52159  P87-1018  P85-1004         1987        3.0        1985
# 4922   P87-1026  C86-1130         1987        1.0        1986
# 52136  P87-1026  P80-1030         1987        2.0        1980
# 52153  P87-1027  P84-1075         1987        1.0        1984
# 52148  P87-1028  P84-1065         1987        1.0        1984
# 52187  A88-1002  P85-1019         1988        1.0        1985
# 52160  A88-1026  P85-1008         1988        1.0        1985
# 52189  A88-1026  P86-1005         1988        2.0        1986
# 52196  A88-1026  P87-1005         1988        3.0        1987
# 52140  A88-1027  P82-1015         1988        1.0        1982
# 52161  A88-1032  P85-1008         1988        1.0        1985
# 18504  A88-1033  J79-1061         1988        1.0        1979
# 52141  A88-1033  P82-1015         1988        2.0        1982
# 52150  C88-1012  P84-1075         1988        1.0        1984
# ...         ...       ...          ...        ...         ...
# 34291  W14-6205  P05-1001         2014        1.0        2005
# 37477  W14-6205  P06-1027         2014        2.0        2006
# 57939  W14-6205  W03-0419         2014        3.0        2003
# 26340  W14-6206  N12-1049         2014        1.0        2012
# 54375  W14-6206  S10-1071         2014        2.0        2010
# 1112   P15-1001  C00-2090         2015        1.0        2000
# 4875   P15-1001  C14-1015         2015        2.0        2014
# 10933  P15-1001  D10-1015         2015        3.0        2010
# 14025  P15-1001  D14-1005         2015        4.0        2014
# 14029  P15-1001  D14-1179         2015        5.0        2014
# 20698  P15-1001  N03-4001         2015        6.0        2003
# 24960  P15-1001  N09-2062         2015        7.0        2009
# 26197  P15-1001  N12-1021         2015        8.0        2012
# 26258  P15-1001  N12-1035         2015        9.0        2012
# 74950  N04-1020  W99-0632         2004        8.0        1999
# 74951  P00-1065  W99-0632         2000        4.0        1999
# 74953  W02-1016  W99-0632         2002        4.0        1999
# 74958  C10-2040  W99-0633         2010        2.0        1999
# 74960  N06-1042  W99-0633         2006        4.0        1999
# 74961  P06-2100  W99-0633         2006        4.0        1999
# 74962  W04-0109  W99-0703         2004        4.0        1999
# 74964  E09-1031  W99-0705         2009       10.0        1999
# 74965  H05-1006  W99-0705         2005        2.0        1999
# 74968  P00-1017  W99-0706         2000        4.0        1999
# 74969  P02-1055  W99-0706         2002       10.0        1999
# 74972  C04-1173  W99-0901         2004        2.0        1999
# 74975  P08-1057  W99-0901         2008        4.0        1999
# 74986  P13-1118  W99-0904         2013        8.0        1999
# 74990  W04-2010  W99-0904         2004        4.0        1999
# 74992  A00-2011  W99-0905         2000        2.0        1999
# 74996  W04-3208  W99-0905         2004        4.0        1999
# 74998  D11-1029  W99-0906         2011       10.0        1999
# 75000  N09-1005  W99-0906         2009       20.0        1999
# 75003  P12-1017  W99-0906         2012        8.0        1999
# 75004  P13-1036  W99-0906         2013       14.0        1999
#
# [34105 rows x 5 columns]

# %%
aan_links_train = aan_links[(aan_links.year_citing < 2013)|((aan_links.year_citing >= 2013)&(aan_links.cite_rank%2 == 0))]

# %%
aan_links_test = aan_links[(aan_links.year_citing >= 2013)&(aan_links.cite_rank%2 == 1)]

# %%
aan_links_train.shape
# Out:
# (61941, 5)

# %%
aan_links_test.shape
# Out:
# (13068, 5)

# %%
aan_links.to_csv('aan_links_years.csv', index=False)

# %%
aan_links_train.to_csv('aan_links_train_2013.csv', index=False)

# %%
aan_links_test.to_csv('aan_links_test_2013.csv', index=False)

# %%
def generate_negative_edges(graph, num_edges):
    negative_edges = set()
    nodes = list(graph.nodes())
    while len(negative_edges) < num_edges:
        i = random.randint(0, len(nodes) - 1)
        j = random.randint(0, len(nodes) - 1)
        if graph.has_edge(nodes[i], nodes[j]):
            continue
        negative_edges.add((nodes[i], nodes[j]))
    return negative_edges

# %%
negative_edges = generate_negative_edges(G, 100)

# %%
list(negative_edges)
# Out:
# [('W08-0315', 'E14-1017'),
#  ('W14-0401', 'W06-2930'),
#  ('W12-1640', 'C94-2149'),
#  ('W01-0703', 'W11-0604'),
#  ('W10-3707', 'C04-1164'),
#  ('W97-0311', 'P13-2138'),
#  ('W10-2410', 'D10-1098'),
#  ('W97-1304', 'P06-2067'),
#  ('W10-3713', 'C10-2011'),
#  ('W12-4210', 'E14-1052'),
#  ('W12-6212', 'W05-1201'),
#  ('W14-1817', 'W04-0405'),
#  ('P08-1086', 'C10-2056'),
#  ('D11-1148', 'W10-1823'),
#  ('S13-2019', 'P09-1042'),
#  ('S13-2058', 'P10-4012'),
#  ('W11-1418', 'P07-1053'),
#  ('C94-2110', 'P11-1052'),
#  ('P11-1062', 'W06-1601'),
#  ('W13-2204', 'D13-1152'),
#  ('I08-2086', 'W10-1612'),
#  ('C04-1025', 'S12-1043'),
#  ('W14-5814', 'W09-0211'),
#  ('C94-2133', 'W10-4343'),
#  ('N10-1095', 'P13-1088'),
#  ('W12-2503', 'S13-1026'),
#  ('N13-1036', 'S12-1098'),
#  ('P11-1100', 'P14-1126'),
#  ('W02-0905', 'D10-1113'),
#  ('I08-3010', 'E09-1046'),
#  ('P14-2082', 'W06-1658'),
#  ('D07-1035', 'D10-1039'),
#  ('N09-2025', 'P06-1083'),
#  ('W08-2132', 'C10-1051'),
#  ('W04-3242', 'P15-1002'),
#  ('W11-1919', 'A94-1009'),
#  ('C04-1047', 'P01-1053'),
#  ('W04-0713', 'W12-3712'),
#  ('H89-2050', 'E09-2015'),
#  ('D10-1067', 'W00-1326'),
#  ('P08-1097', 'S12-1105'),
#  ('W12-2306', 'W00-1318'),
#  ('N06-4004', 'W11-1009'),
#  ('W12-3805', 'D10-1001'),
#  ('W12-2605', 'P07-1128'),
#  ('D09-1134', 'W09-3102'),
#  ('N09-1051', 'W10-3505'),
#  ('W09-3538', 'W11-2119'),
#  ('P08-2029', 'P05-2016'),
#  ('C10-2155', 'C96-1085'),
#  ('P06-2123', 'N06-3006'),
#  ('S12-1058', 'W09-2110'),
#  ('P13-1081', 'P10-1043'),
#  ('W04-0602', 'D08-1068'),
#  ('P09-1007', 'P14-2086'),
#  ('W09-0703', 'W93-0310'),
#  ('W11-2021', 'W13-2506'),
#  ('W97-0411', 'W07-1109'),
#  ('W07-1909', 'W06-0136'),
#  ('W07-1422', 'W11-1704'),
#  ('H05-1019', 'W10-0214'),
#  ('P11-2094', 'A94-1006'),
#  ('I08-2102', 'W12-4509'),
#  ('D09-1036', 'E14-1072'),
#  ('W05-1002', 'W13-2407'),
#  ('S14-2014', 'P87-1010'),
#  ('C14-1106', 'E14-1011'),
#  ('W06-2936', 'E14-1062'),
#  ('W14-0310', 'W13-4060'),
#  ('E14-1059', 'D09-1128'),
#  ('W03-1302', 'E12-1058'),
#  ('W06-0116', 'W12-2206'),
#  ('W13-2132', 'N13-2007'),
#  ('W11-1905', 'W07-2202'),
#  ('P05-1058', 'W10-4119'),
#  ('E14-3006', 'W03-1802'),
#  ('W13-2010', 'W06-1664'),
#  ('P10-2003', 'C90-3008'),
#  ('W97-0202', 'P13-1123'),
#  ('D08-1096', 'W06-1503'),
#  ('W10-3020', 'P06-4010'),
#  ('W03-1717', 'W07-1904'),
#  ('W03-2108', 'W08-2230'),
#  ('W99-0907', 'E14-1006'),
#  ('C14-1077', 'E99-1011'),
#  ('P07-2044', 'P13-2086'),
#  ('S12-1072', 'D08-1079'),
#  ('W10-3006', 'W07-1411'),
#  ('P14-1068', 'P11-1149'),
#  ('P11-2029', 'S12-1059'),
#  ('W06-0503', 'W07-1215'),
#  ('C14-1069', 'P09-1075'),
#  ('S14-2077', 'E95-1022'),
#  ('W14-3209', 'C14-2028'),
#  ('W07-0814', 'P09-1029'),
#  ('W10-2006', 'C08-1042'),
#  ('P01-1043', 'P13-2049'),
#  ('W04-1010', 'P06-1056'),
#  ('C90-3099', 'W10-0102'),
#  ('N13-1055', 'E14-4016')]
